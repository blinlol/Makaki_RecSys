# %%
from split import leave_one_out_split, remove_last_item, get_last_item
from make_features import make_features_before, make_features_after
import pandas as pd
import numpy as np
import catboost as cb
from sklearn.metrics import roc_auc_score

# %%
zvuk = pd.read_parquet('test_zvuk.parquet')
smm = pd.read_parquet('test_smm.parquet')

# %%
ranks = pd.read_csv('SASRec_ranks-2.csv', index_col=0)
ranks.head()
# Out:
#    user_id  item_id  prediction
# 0  1000010    35107   10.983168
# 1  1000010     2259   10.869387
# 2  1000010     7748   10.736988
# 3  1000010   112389   10.644200
# 4  1000010   114081   10.595426

# %%
train_smm, _, test_smm = leave_one_out_split(make_features_before(smm), validation_size=0)

# %%
def add_target(train: pd.DataFrame, test: pd.DataFrame) -> pd.DataFrame:
    last_item = get_last_item(test)

    merged = train.merge(last_item, on=['user_id', 'item_id'], how='left', indicator=True)
    train['target'] = (merged['_merge'] == 'both').astype(int)

    return train

# %%
output = add_target(ranks, test_smm)

# %%
output_featured = make_features_after(output)

# %%
output_featured.head()
# Out:
#          user_id  item_id  prediction  target  rank
# 1995750  3298628    56394   15.523580       0     1
# 1938050  3231979   153868   15.092383       0     1
# 1938051  3231979    74961   15.042010       0     2
# 6936450  8941978   125722   15.023755       0     1
# 5043050  6779197    36553   14.931406       0     1

# %%
model = cb.CatBoostClassifier(iterations=100, learning_rate=0.1, random_seed=42)

# %%
def train_model(X_train, y_train, model):
    model.fit(X_train, y_train)
    return model

# %%
def predict(X_test, model):
    result = model.predict_proba(X_test)
    X_test['score'] = result[:, 0]
    return X_test

# %%
def predict_list(X_test, model):
    result = model.predict_proba(X_test)
    X_test['score'] = result[:, 0]
    output = X_test.groupby('user_id').apply(lambda x: x.sort_values('score', ascending=False).head(10)['item_id'].tolist())
    return pd.DataFrame({'user_id': output.index, 'item_id': output.values})

# %%
X_train, y_train = output_featured.drop('target', axis=1), output_featured['target']

# %%
model = train_model(X_train, y_train, model)
# Out:
# 0:	learn: 0.5992761	total: 764ms	remaining: 1m 15s
# 1:	learn: 0.5227166	total: 1.31s	remaining: 1m 4s
# 2:	learn: 0.4593001	total: 1.88s	remaining: 1m
# 3:	learn: 0.4053060	total: 2.44s	remaining: 58.5s
# 4:	learn: 0.3592009	total: 2.88s	remaining: 54.7s
# 5:	learn: 0.3195233	total: 3.4s	remaining: 53.3s
# 6:	learn: 0.2851730	total: 4s	remaining: 53.1s
# 7:	learn: 0.2552152	total: 4.58s	remaining: 52.7s
# 8:	learn: 0.2291313	total: 5.11s	remaining: 51.6s
# 9:	learn: 0.2061326	total: 5.66s	remaining: 50.9s
# 10:	learn: 0.1858297	total: 6.19s	remaining: 50.1s
# 11:	learn: 0.1679449	total: 6.58s	remaining: 48.2s
# 12:	learn: 0.1520727	total: 7.14s	remaining: 47.8s
# 13:	learn: 0.1380449	total: 7.65s	remaining: 47s
# 14:	learn: 0.1255415	total: 8.21s	remaining: 46.5s
# 15:	learn: 0.1144395	total: 8.77s	remaining: 46s
# 16:	learn: 0.1045341	total: 9.22s	remaining: 45s
# 17:	learn: 0.0956989	total: 9.7s	remaining: 44.2s
# 18:	learn: 0.0878246	total: 10.2s	remaining: 43.7s
# 19:	learn: 0.0807786	total: 10.8s	remaining: 43.1s
# 20:	learn: 0.0744842	total: 11.3s	remaining: 42.3s
# 21:	learn: 0.0688557	total: 11.7s	remaining: 41.6s
# 22:	learn: 0.0638238	total: 12.3s	remaining: 41.1s
# 23:	learn: 0.0593335	total: 12.8s	remaining: 40.6s
# 24:	learn: 0.0553067	total: 13.2s	remaining: 39.7s
# 25:	learn: 0.0517030	total: 13.7s	remaining: 38.9s
# 26:	learn: 0.0484809	total: 14.1s	remaining: 38s
# 27:	learn: 0.0456014	total: 14.6s	remaining: 37.4s
# 28:	learn: 0.0430204	total: 15.1s	remaining: 36.9s
# 29:	learn: 0.0407135	total: 15.6s	remaining: 36.4s
# 30:	learn: 0.0386595	total: 16.1s	remaining: 35.9s
# 31:	learn: 0.0368301	total: 16.6s	remaining: 35.3s
# 32:	learn: 0.0351910	total: 17.2s	remaining: 34.9s
# 33:	learn: 0.0337319	total: 17.7s	remaining: 34.3s
# 34:	learn: 0.0324216	total: 18.2s	remaining: 33.7s
# 35:	learn: 0.0312585	total: 18.7s	remaining: 33.2s
# 36:	learn: 0.0302311	total: 19.2s	remaining: 32.7s
# 37:	learn: 0.0293130	total: 19.7s	remaining: 32.2s
# 38:	learn: 0.0284895	total: 20.3s	remaining: 31.7s
# 39:	learn: 0.0277653	total: 20.8s	remaining: 31.2s
# 40:	learn: 0.0271313	total: 21.3s	remaining: 30.6s
# 41:	learn: 0.0265668	total: 21.8s	remaining: 30.1s
# 42:	learn: 0.0260573	total: 22.3s	remaining: 29.6s
# 43:	learn: 0.0256110	total: 22.9s	remaining: 29.1s
# 44:	learn: 0.0252134	total: 23.4s	remaining: 28.6s
# 45:	learn: 0.0248656	total: 23.9s	remaining: 28s
# 46:	learn: 0.0245635	total: 24.4s	remaining: 27.5s
# 47:	learn: 0.0242986	total: 25s	remaining: 27s
# 48:	learn: 0.0240590	total: 25.5s	remaining: 26.6s
# 49:	learn: 0.0238545	total: 26.1s	remaining: 26.1s
# 50:	learn: 0.0236743	total: 26.5s	remaining: 25.5s
# 51:	learn: 0.0235168	total: 27.1s	remaining: 25s
# 52:	learn: 0.0233752	total: 27.6s	remaining: 24.5s
# 53:	learn: 0.0232529	total: 28.2s	remaining: 24s
# 54:	learn: 0.0231476	total: 28.8s	remaining: 23.6s
# 55:	learn: 0.0230566	total: 29.2s	remaining: 23s
# 56:	learn: 0.0229900	total: 29.8s	remaining: 22.5s
# 57:	learn: 0.0229185	total: 30.3s	remaining: 21.9s
# 58:	learn: 0.0228586	total: 30.8s	remaining: 21.4s
# 59:	learn: 0.0228055	total: 31.3s	remaining: 20.8s
# 60:	learn: 0.0227647	total: 31.8s	remaining: 20.4s
# 61:	learn: 0.0227239	total: 32.3s	remaining: 19.8s
# 62:	learn: 0.0226902	total: 32.9s	remaining: 19.3s
# 63:	learn: 0.0226611	total: 33.4s	remaining: 18.8s
# 64:	learn: 0.0226424	total: 33.8s	remaining: 18.2s
# 65:	learn: 0.0226203	total: 34.2s	remaining: 17.6s
# 66:	learn: 0.0226013	total: 34.8s	remaining: 17.1s
# 67:	learn: 0.0225842	total: 35.2s	remaining: 16.6s
# 68:	learn: 0.0225702	total: 35.7s	remaining: 16.1s
# 69:	learn: 0.0225584	total: 36.3s	remaining: 15.5s
# 70:	learn: 0.0225477	total: 36.8s	remaining: 15s
# 71:	learn: 0.0225391	total: 37.3s	remaining: 14.5s
# 72:	learn: 0.0225311	total: 37.9s	remaining: 14s
# 73:	learn: 0.0225252	total: 38.4s	remaining: 13.5s
# 74:	learn: 0.0225190	total: 39s	remaining: 13s
# 75:	learn: 0.0225142	total: 39.5s	remaining: 12.5s
# 76:	learn: 0.0225102	total: 40.1s	remaining: 12s
# 77:	learn: 0.0225067	total: 40.7s	remaining: 11.5s
# 78:	learn: 0.0225036	total: 41.2s	remaining: 10.9s
# 79:	learn: 0.0225011	total: 41.6s	remaining: 10.4s
# 80:	learn: 0.0224987	total: 42.1s	remaining: 9.88s
# 81:	learn: 0.0224967	total: 42.7s	remaining: 9.37s
# 82:	learn: 0.0224951	total: 43.2s	remaining: 8.85s
# 83:	learn: 0.0224933	total: 43.7s	remaining: 8.33s
# 84:	learn: 0.0224916	total: 44.3s	remaining: 7.81s
# 85:	learn: 0.0224900	total: 44.7s	remaining: 7.28s
# 86:	learn: 0.0224888	total: 45.3s	remaining: 6.77s
# 87:	learn: 0.0224877	total: 45.8s	remaining: 6.25s
# 88:	learn: 0.0224867	total: 46.3s	remaining: 5.72s
# 89:	learn: 0.0224860	total: 46.8s	remaining: 5.2s
# 90:	learn: 0.0224851	total: 47.3s	remaining: 4.68s
# 91:	learn: 0.0224846	total: 47.7s	remaining: 4.15s
# 92:	learn: 0.0224839	total: 48.3s	remaining: 3.63s
# 93:	learn: 0.0224831	total: 48.7s	remaining: 3.11s
# 94:	learn: 0.0224825	total: 49.2s	remaining: 2.59s
# 95:	learn: 0.0224816	total: 49.8s	remaining: 2.08s
# 96:	learn: 0.0224810	total: 50.2s	remaining: 1.55s
# 97:	learn: 0.0224806	total: 50.7s	remaining: 1.03s
# 98:	learn: 0.0224801	total: 51.2s	remaining: 517ms
# 99:	learn: 0.0224795	total: 51.6s	remaining: 0us

# %%
predicted = predict(X_train, model)

# %%
predicted.sort_index()
# Out:
#          user_id  item_id  prediction  sequence_length  freq_item  \
# 0        1000010    35107   10.983168               50   0.000098
# 1        1000010     2259   10.869387               50   0.001337
# 2        1000010     7748   10.736988               50   0.000217
# 3        1000010   112389   10.644200               50   0.000301
# 4        1000010   114081   10.595426               50   0.000210
# ...          ...      ...         ...              ...        ...
# 7862695  9999982   102290    8.284018               50   0.000098
# 7862696  9999982    56543    8.247368               50   0.001351
# 7862697  9999982    56929    8.246140               50   0.000203
# 7862698  9999982    37454    8.241319               50   0.000343
# 7862699  9999982   109305    8.232973               50   0.000357
#
#          freq_user_mean  freq_user_max  freq_user_quantile_25  \
# 0              0.000319       0.001337               0.000102
# 1              0.000319       0.001337               0.000102
# 2              0.000319       0.001337               0.000102
# 3              0.000319       0.001337               0.000102
# 4              0.000319       0.001337               0.000102
# ...                 ...            ...                    ...
# 7862695        0.000674       0.002772               0.000322
# 7862696        0.000674       0.002772               0.000322
# 7862697        0.000674       0.002772               0.000322
# 7862698        0.000674       0.002772               0.000322
# 7862699        0.000674       0.002772               0.000322
#
#          freq_user_quantile_50  freq_user_quantile_75  rank     score
# 0                     0.000235               0.000389     1  0.954032
# 1                     0.000235               0.000389     2  0.976395
# 2                     0.000235               0.000389     3  0.976813
# 3                     0.000235               0.000389     4  0.983519
# 4                     0.000235               0.000389     5  0.983593
# ...                        ...                    ...   ...       ...
# 7862695               0.000497               0.000900    46  0.996921
# 7862696               0.000497               0.000900    47  0.997553
# 7862697               0.000497               0.000900    48  0.997338
# 7862698               0.000497               0.000900    49  0.997516
# 7862699               0.000497               0.000900    50  0.997529
#
# [7862700 rows x 12 columns]

# %%
roc_auc_score(y_train.sort_index(), predicted.sort_index()['score'])
# Out:
# 0.21731249971387528
